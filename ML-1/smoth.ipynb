# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000, n_features=2, n_clusters_per_class=1, weights=[0.90], n_redundant=0, random_state=1)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(X, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=["target"])

# %%
final = pd.concat([df1, df2], axis=1)

# %%
final
# Out:
#            f1        f2  target
# 0    1.536830 -1.398694       1
# 1    1.551108  1.810329       0
# 2    1.293619  1.010946       0
# 3    1.119889  1.632518       0
# 4    1.042356  1.121529       0
# ..        ...       ...     ...
# 995  2.210439  2.006772       0
# 996  1.910941  2.011860       0
# 997 -0.556625 -0.159837       0
# 998  1.004999  0.936290       0
# 999  1.462110  1.144978       0
#
# [1000 rows x 3 columns]

# %%
final["target"].value_counts()
# Out:
# target
# 0    894
# 1    106
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final['f1'], final['f2'], c=final['target'])

# %%
from imblearn.over_sampling import SMOTE

# %%
## transform the dataset 
oversample = SMOTE()
X,y = oversample.fit_resample(final[['f1', 'f2']], final[['target']])

# %%
X.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788, 1)

# %%
y[y==0].value_counts()
# Out:
# target
# 0.0       894
# Name: count, dtype: int64

# %%
y[y==1].value_counts()
# Out:
# target
# 1.0       894
# Name: count, dtype: int64

# %%
df3 = pd.DataFrame(X, columns=['f1','f2'])
df4 = pd.DataFrame(y, columns=["target"])
oversampled = pd.concat([df3,df4], axis=1)

# %%
plt.scatter(oversampled['f1'], oversampled['f2'], c=oversampled['target'])
